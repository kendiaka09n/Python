# %% [markdown]
# # Machine Learning e Data Science

# %% [markdown]
# # Entrega 01 - Portal  Gov.br

# %% [markdown]
# ## Professor Diogenes A. R. Justo

# %% [markdown]
# A equipe Ômega foi selecionada para participar de um evento competitivo, onde o stakeholder desafiou os participantes a encontrar soluções disruptivas para solucionar sua dor, de **melhorar a experiência do usuário na utilização do portal Gov.br**. Um dos pontos levantados pelo stakeholder é o desejo que até uma pessoa que tenha poucos conhecimentos de informática consigam achar seus conteúdos e aproveitar os recursos do governo, **diminuindo a distância Governo X Cidadão**.

# %%
Nome = ['Fabio Akamine','Gabriel Mora','Gustavo Oliveira','Rafaela Almeida' ]
rm = [86294, 84816,85372,84782]
 
#create dataframe using two list days and temperature
Componentes_Equipe_Omega = pd.DataFrame({"NOME":Nome, "rm":RM})
Componentes_Equipe_Omega
# Out:
#                NOME     rm
# 0     Fabio Akamine  86294
# 1      Gabriel Mora  84816
# 2  Gustavo Oliveira  85372
# 3   Rafaela Almeida  84782

# %% [markdown]
# #  Introdução

# %% [markdown]
# Este trabalho tem como objetivo agariar informações a respeito das motivações do usuários e seu perfil ao utilizar o portal Gov.
#
# A base desta análise exploratória foi retirado do site do Fale.BR (Plataforma Integrada de Ouvidoria e Acesso à Informação - https://falabr.cgu.gov.br/publico/DownloadDados/DownloadDadosLai.aspx) e da API de Serviços do Portal de Serviços (https://www.servicos.gov.br/api/v1/docs#/)
#
# Na ausência do acesso a fonte de dados referente ao perfil de acesso ao portal Gov.br, utilizaremos as informações de avaliação dos servicos, do **Portal de Serviços**) e do perfil de usuários que encaminham reclamações ou requisições de informação na **Plataforma Integrada de Ouvidoria e Acesso à Informação**.
#
# Para início de trabalho, fizemos um brainstorm com os principais assuntos/problemas que o portal poderia estar enfrentando, onde o assunto a ser resolvido é a "Baixa aderência ao Portal Gov".

# %%
Image("mindmap.png")

# %% [markdown]
# ##  0.0. Imports

# %% [markdown]
# ###  0.1. Bibliotecas

# %%
import requests
import json
import fsspec
import math
from datetime import datetime
from heatmap import heatmap, corrplot



import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

from datetime import date
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from pandas.io.json import json_normalize
from IPython.display import Image
from IPython.core.display import HTML

import warnings
warnings.filterwarnings('ignore')


sns.set()

# %% [markdown]
# ###  0.2. Fonte de dados

# %%
#Plataforma Integrada de Ouvidoria e Acesso à Informação - Reclamacao
##Os arquivos do tipo csv passaram inicialmente pelo Notepad++ para que seu encoding fosse "atualizado" para o UTF-8. 
###Foi feito o merge dos arquivos de dicionario, recurso de reclamação e reclamação. 
df_raw_solicitante_reclamacao2020 = pd.read_csv("Reclamacao_2020/20210401_SolicitantesRecursos_csv_2020_utf8.txt", sep=";", encoding =  "utf_8", header = None)
df_raw_recurso_reclamacao2020 = pd.read_csv("Reclamacao_2020/20210401_Recursos_Reclamacoes_csv_2020_utf8.txt", sep=";", encoding =  "utf_8", header = None)
df_raw_recurso_dict_reclamacao2020 = pd.read_csv("Reclamacao_2020/Recursos-Formato.txt", encoding = "ANSI", sep = "-",  skiprows=2 )
df_raw_solicitante_dict_reclamacao2020 = pd.read_csv("Reclamacao_2020/Solicitantes-Formato.txt", encoding = "ANSI", sep = "-",  skiprows=2 )

df = df_raw_solicitante_reclamacao2020.copy()
df_dict = df_raw_solicitante_dict_reclamacao2020.copy()
coluna_dict = df_dict['Unnamed: 1'].tolist()
df_sol_reclama = df.set_axis(coluna_dict, axis=1)
df_sol_reclama.rename(columns=lambda x: x.strip(), inplace=True)

df = df_raw_recurso_reclamacao2020.copy()
df_dict = df_raw_recurso_dict_reclamacao2020.copy()
coluna_dict = df_dict['Unnamed: 1'].tolist()
df_recurso_reclama = df.set_axis(coluna_dict, axis=1)
df_recurso_reclama.rename(columns=lambda x: x.strip(), inplace=True)

df_reclamacoes= pd.merge(df_recurso_reclama, df_sol_reclama , on='IdSolicitante', how='left')
## a extensão Y é referente ao solicitante e x ao orgão do governo


#Plataforma Integrada de Ouvidoria e Acesso à Informação - Pedido Acesso á informação
##Os arquivos do tipo csv passaram inicialmente pelo Notepad++ para que seu encoding fosse "atualizado" para o UTF-8. 
###Foi feito o merge dos arquivos de dicionario, pedido de acesso a informação e de solicitação. . 
df_raw_solicitante_acesso2020 = pd.read_csv("pedido_acesso_info_2020/20210401_SolicitantesPedidos_csv_2020_utf8.txt", sep=";", encoding =  "utf_8", header = None)
df_raw_pedido_acesso2020 = pd.read_csv("pedido_acesso_info_2020/20210401_Pedidos_csv_2020_utf8.txt", sep=";", encoding =  "utf_8", header = None)
df_raw_pedido_dict_acesso2020 = pd.read_csv("pedido_acesso_info_2020/Pedidos-Formato.txt", encoding = "ANSI", sep = "-", skiprows=2 )
df_raw_solicitante_dict_acesso2020 = pd.read_csv("pedido_acesso_info_2020/Solicitantes-Formato.txt", encoding = "ANSI", sep = "-", skiprows=2 )

df = df_raw_solicitante_acesso2020.copy()
df_dict = df_raw_solicitante_dict_acesso2020.copy()
coluna_dict = df_dict['Unnamed: 1'].tolist()
df_sol_info = df.set_axis(coluna_dict, axis=1)
df_sol_info.rename(columns=lambda x: x.strip(), inplace=True)

df = df_raw_pedido_acesso2020.copy()
df_dict = df_raw_pedido_dict_acesso2020.copy()
coluna_dict = df_dict['Unnamed: 1'].tolist()
df_pedido_info = df.set_axis(coluna_dict, axis=1)
df_pedido_info.rename(columns=lambda x: x.strip(), inplace=True)

df_pedido_info= pd.merge(df_pedido_info, df_sol_info , on='IdSolicitante', how='left')
## a extensão Y é referente ao solicitante e x ao orgão do governo


#API de Serviços da API Portal de Serviços
url = 'https://www.servicos.gov.br/api/v1/servicos'
headers = {'content-type': 'application/json'}
r = requests.get(url, headers=headers).json()
df_raw_apiServico = pd.json_normalize(r, record_path =['resposta'])
df_raw_apiServico = pd.DataFrame(df_raw_apiServico)

# %%
#API de Serviços da API Portal de Serviços
url = 'https://www.servicos.gov.br/api/v1/servicos'
headers = {'content-type': 'application/json'}
r = requests.get(url, headers=headers).json()
df_raw_apiServico = pd.json_normalize(r, record_path =['resposta'])

# %% [markdown]
# ##  1.0. Descrição dos Dados

# %%
print('O dataset de pedido de informação possui {} linhas'.format(df_pedido_info.shape[0]))
print('O dataset de pedido de reclamações possui {} linhas'.format(df_reclamacoes.shape[0]))
print('O dataset da API de serviços possui {} linhas'.format(df_raw_apiServico.shape[0]))
# Out:
# O dataset de pedido de informação possui 154075 linhas
# O dataset de pedido de reclamações possui 18773 linhas
# O dataset da API de serviços possui 4270 linhas

# %%
df_raw_apiServico.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4270 entries, 0 to 4269
# Data columns (total 60 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   id                                      4270 non-null   object
#  1   nome                                    4270 non-null   object
#  2   sigla                                   3501 non-null   object
#  3   descricao                               4270 non-null   object
#  4   contato                                 4270 non-null   object
#  5   gratuito                                4270 non-null   object
#  6   porcentagemDigital                      4256 non-null   float64
#  7   porcentagemManual                       800 non-null    object
#  8   servicoDigital                          4270 non-null   bool
#  9   linkServicoDigital                      3487 non-null   object
#  10  condicoesAcessibilidade                 4270 non-null   object
#  11  tratamentoPrioritario                   4270 non-null   object
#  12  tratamentoDispensadoAtendimento         4270 non-null   object
#  13  etapas                                  4270 non-null   object
#  14  tempoMediaEspera                        4256 non-null   object
#  15  percentualAvaliacoesPositivas           4256 non-null   object
#  16  url                                     4270 non-null   object
#  17  solicitantes.solicitante                4270 non-null   object
#  18  tempoTotalEstimado.ate.max              852 non-null    object
#  19  tempoTotalEstimado.ate.unidade          852 non-null    object
#  20  tempoTotalEstimado.entre                0 non-null      float64
#  21  tempoTotalEstimado.emMedia              0 non-null      float64
#  22  tempoTotalEstimado.atendimentoImediato  0 non-null      float64
#  23  tempoTotalEstimado.naoEstimadoAinda     0 non-null      float64
#  24  tempoTotalEstimado.descricao            800 non-null    object
#  25  tempoTotalEstimado.min                  1104 non-null   float64
#  26  tempoTotalEstimado.max                  2321 non-null   float64
#  27  validadeDocumento.tipo                  2893 non-null   object
#  28  validadeDocumento.quantidade            2893 non-null   object
#  29  validadeDocumento.unidade               2893 non-null   object
#  30  validadeDocumento.descricao             3501 non-null   object
#  31  orgao.id                                4270 non-null   object
#  32  orgao.dbId                              4270 non-null   int64
#  33  orgao.nomeOrgao                         4270 non-null   object
#  34  orgao.porcentagemDigital                0 non-null      object
#  35  orgao.tempoMedioEspera                  0 non-null      object
#  36  orgao.porcentagemAvaliacoesPositivas    0 non-null      object
#  37  orgao.qtdTotal                          0 non-null      object
#  38  orgao.qtdTotalSolicitacoes              0 non-null      object
#  39  orgao.qtdDenuncias                      0 non-null      object
#  40  orgao.qtdReclamacao                     0 non-null      object
#  41  segmentosDaSociedade.item               4270 non-null   object
#  42  areasDeInteresse.item                   4270 non-null   object
#  43  palavrasChave.item                      3501 non-null   object
#  44  avaliacoes.positivas                    4256 non-null   float64
#  45  avaliacoes.negativas                    4256 non-null   float64
#  46  legislacoes.item                        3000 non-null   object
#  47  nomesPopulares.item                     3436 non-null   object
#  48  tempoTotalEstimado.ate                  0 non-null      float64
#  49  tempoTotalEstimado.entre.min            1104 non-null   object
#  50  tempoTotalEstimado.entre.max            1104 non-null   object
#  51  tempoTotalEstimado.entre.unidade        1104 non-null   object
#  52  servicosRelacionados                    314 non-null    object
#  53  servicoIndisponivel                     307 non-null    float64
#  54  totalSimplifique                        219 non-null    object
#  55  simplifiqueSolicitacoes                 219 non-null    object
#  56  simplifiqueDenuncias                    219 non-null    object
#  57  simplifiqueReclamacoes                  219 non-null    object
#  58  tempoTotalEstimado.emMedia.max          365 non-null    object
#  59  tempoTotalEstimado.emMedia.unidade      365 non-null    object
# dtypes: bool(1), float64(11), int64(1), object(47)
# memory usage: 1.9+ MB

# %%
df_pedido_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 154075 entries, 0 to 154074
# Data columns (total 28 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   IdPedido              154075 non-null  int64
#  1   ProtocoloPedido       154075 non-null  int64
#  2   Esfera                154075 non-null  object
#  3   UF_x                  452 non-null     object
#  4   Municipio_x           452 non-null     object
#  5   OrgaoDestinatario     154075 non-null  object
#  6   Situacao              154075 non-null  object
#  7   DataRegistro          154075 non-null  object
#  8   PrazoAtendimento      154071 non-null  object
#  9   FoiProrrogado         154075 non-null  object
#  10  FoiReencaminhado      154075 non-null  object
#  11  FormaResposta         154075 non-null  object
#  12  OrigemSolicitacao     154075 non-null  object
#  13  IdSolicitante         154075 non-null  int64
#  14  AssuntoPedido         154025 non-null  object
#  15  SubAssuntoPedido      1728 non-null    object
#  16  DataResposta          153858 non-null  object
#  17  Decisao               153847 non-null  object
#  18  EspecificacaoDecisao  108318 non-null  object
#  19  TipoDemandante        122510 non-null  object
#  20  DataNascimento        74183 non-null   object
#  21  Genero                80240 non-null   object
#  22  Escolaridade          72589 non-null   object
#  23  Profissao             71272 non-null   object
#  24  TipoPessoaJuridica    7102 non-null    object
#  25  Pais                  107130 non-null  object
#  26  UF_y                  82853 non-null   object
#  27  Municipio_y           82853 non-null   object
# dtypes: int64(3), object(25)
# memory usage: 34.1+ MB

# %%
df_reclamacoes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18773 entries, 0 to 18772
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   IdRecurso            18773 non-null  int64
#  1   IdRecursoPrecedente  5732 non-null   float64
#  2   IdPedido             18773 non-null  int64
#  3   IdSolicitante        18773 non-null  int64
#  4   ProtocoloPedido      18773 non-null  int64
#  5   Esfera               18773 non-null  object
#  6   UF_x                 9 non-null      object
#  7   Municipio_x          9 non-null      object
#  8   OrgaoDestinatario    18773 non-null  object
#  9   Instancia            18773 non-null  object
#  10  Situacao             18773 non-null  object
#  11  DataRegistro         18773 non-null  object
#  12  PrazoAtendimento     18773 non-null  object
#  13  OrigemSolicitacao    18773 non-null  object
#  14  TipoRecurso          18773 non-null  object
#  15  DataResposta         17476 non-null  object
#  16  TipoResposta         17476 non-null  object
#  17  TipoDemandante       13808 non-null  object
#  18  DataNascimento       7923 non-null   object
#  19  Genero               8942 non-null   object
#  20  Escolaridade         7781 non-null   object
#  21  Profissao            7625 non-null   object
#  22  TipoPessoaJuridica   780 non-null    object
#  23  Pais                 11577 non-null  object
#  24  UF_y                 9031 non-null   object
#  25  Municipio_y          9031 non-null   object
# dtypes: float64(1), int64(4), object(21)
# memory usage: 3.9+ MB

# %% [markdown]
# ### 1.1. Ajuste de colunas e variáveis

# %%
#Plataforma Integrada de Ouvidoria e Acesso à Informação - Pedido Acesso á informação
#Foi selecionado apenas os usuários com identificação

df_info = df_pedido_info.copy()
df_info [ 'identificacao'] =  df_info['IdSolicitante'].apply(lambda x: "anonimo" if x == 0 else 'identificado')
df_info.Profissao.fillna('nao_identificado', inplace=True)
df_info['contagem'] = 1


##Separação do dataset para os usuários identificados
df_usuario_info = df_info.query("identificacao == 'identificado'")
df_info_idade = df_usuario_info.copy()
df_info_idade['DataResposta']= pd.to_datetime(df_info_idade['DataResposta'])
df_info_idade['DataRegistro']= pd.to_datetime(df_info_idade['DataRegistro'])
df_info_idade['sla'] =  df_info_idade.DataResposta - df_info_idade.DataRegistro 

cols_drop = ['IdPedido', 'ProtocoloPedido']
df_info_idade = df_info_idade.drop( cols_drop, axis = 1)

df_info_idade=df_info_idade.dropna(subset = ['DataNascimento'], how = 'all')
data_atual = date.today()
data_em_texto = data_atual.strftime('%d/%m/%Y')
df_info_idade['hoje']= data_em_texto
df_info_idade['hoje']= pd.to_datetime(df_info_idade['hoje'])
df_info_idade['DataNascimento']= pd.to_datetime(df_info_idade['DataNascimento'], errors = 'coerce')
df_info_idade['idade'] =(df_info_idade['hoje'].dt.year - df_info_idade['DataNascimento'].dt.year)
df_info_idade=df_info_idade.dropna(subset = ['idade'], how = 'all')
df_info_idade['idade'] = df_info_idade['idade'].round().astype(int)
df_info_idade['range_idade'] = df_info_idade['idade'].apply(lambda x: '0-16' if x < 16 else '16-25' if x<25 else '25-40' if x <40 else '40-60' if x<60 else '>60')
df_info_idade['mes'] = df_info_idade['DataRegistro'].dt.month


#Plataforma Integrada de Ouvidoria e Acesso à Informação - Pedido Acesso á informação
#Foi selecionado apenas os usuários com identificação
df_reclama = df_reclamacoes.copy()
df_reclama [ 'identificacao'] =  df_reclama['IdSolicitante'].apply(lambda x: "anonimo" if x == 0 else 'identificado')
df_reclama.Profissao.fillna('nao_identificado', inplace=True)
df_reclama['contagem'] = 1


##Separação do dataset para os usuários identificados
df_usuário_reclama = df_reclama.query("identificacao == 'identificado'")
df_reclama_idade = df_usuário_reclama.copy()
df_reclama_idade['DataResposta']= pd.to_datetime(df_reclama['DataResposta'])
df_reclama_idade['DataRegistro']= pd.to_datetime(df_reclama['DataRegistro'])
df_reclama_idade['sla'] =  df_reclama_idade.DataResposta - df_reclama_idade.DataRegistro 

cols_drop = ['IdPedido', 'ProtocoloPedido']
df_reclama_idade = df_reclama_idade.drop( cols_drop, axis = 1)

df_reclama_idade=df_reclama_idade.dropna(subset = ['DataNascimento'], how = 'all')
data_atual = date.today()
data_em_texto = data_atual.strftime('%d/%m/%Y')
df_reclama_idade['hoje']= data_em_texto
df_reclama_idade['hoje']= pd.to_datetime(df_reclama_idade['hoje'])
df_reclama_idade['DataNascimento']= pd.to_datetime(df_reclama_idade['DataNascimento'], errors = 'coerce')
df_reclama_idade['idade'] =(df_reclama_idade['hoje'].dt.year - df_reclama_idade['DataNascimento'].dt.year)
df_reclama_idade=df_reclama_idade.dropna(subset = ['idade'], how = 'all')
df_reclama_idade['idade'] = df_reclama_idade['idade'].round().astype(int)
df_reclama_idade['range_idade'] = df_reclama_idade['idade'].apply(lambda x: '0-16' if x < 16 else '16-25' if x<25 else '25-40' if x <40 else '40-60' if x<60 else '>60')
df_reclama_idade['mes'] = df_reclama_idade['DataRegistro'].dt.month

# %% [markdown]
# ## 2.0. Análise Qualidade dos Dados

# %% [markdown]
# ### 2.1. Análise dos Usuários Anônimos

# %% [markdown]
# Dos dados do portal de acesso à informação, observamos que **a maioria dos usuários se identificaram** e que os 5 principais órgão acessados por estes usuários são **MCIDADANIA - Ministério da Cidadania (Desenvolvimento Social e Esporte), ME - Ministério da Economia, CEF – Caixa Econômica Federal, INSS – Instituto Nacional do Seguro Social, MS – Ministério da Saúde, PETROBRAS – Petróleo Brasileiro S.A.**. É válido indicar que houve uma **ENORME** procura pelo **MCIDADANIA - Ministério da Cidadania (Desenvolvimento Social e Esporte)** no período de 2020.

# %%
# Identificado que a maioria dos usuários do portal de informação se identificaram, sendo a distribuição e do gênero maculino e feminino bem próximos. 
identifica       = df_info[['identificacao']].value_counts().sort_values(ascending= False). reset_index()
genero           = df_info[['Genero']].value_counts().sort_values(ascending= False). reset_index()
orgao            = df_info[['OrgaoDestinatario']].value_counts().sort_values(ascending= False).head(20).reset_index()

print('São {} usuários do anônimos e {} usuários identificados'.format(identifica[0][0], identifica[0][1] ))
print('Os TOP 5 órgãos mais requisitados são {}, {}, {}, {}, {}, {}'.format(orgao['OrgaoDestinatario'][0], orgao['OrgaoDestinatario'][1], orgao['OrgaoDestinatario'][2], orgao['OrgaoDestinatario'][3], orgao['OrgaoDestinatario'][4], orgao['OrgaoDestinatario'][5] ))

plt.figure(figsize=(30,15))

plt.subplot(1,3,2)
sns.barplot(x='identificacao' , y=0 , data = identifica, orient = 'v')
plt.title('IDENTIFICAÇÃO DE ACESSO NO PORTAL DE INFORMAÇÃO (2020)', pad = 20,fontsize = 13, color ='dimgrey', fontweight = 'bold');


plt.subplot(1,3,1)
sns.barplot(x= 0, y= 'OrgaoDestinatario' , data = orgao, orient = 'h')
plt.title('QUANTIFICAÇÃO DE REQUISIÇÃO DE INFORMAÇÃO POR ÓRGÃO  (2020)', pad = 20,fontsize = 13, color ='dimgrey', fontweight = 'bold');
# Out:
# São 122510 usuários do anônimos e 31565 usuários identificados
# Os TOP 5 órgãos mais requisitados são MCIDADANIA - Ministério da Cidadania (Desenvolvimento Social e Esporte), ME - Ministério da Economia, CEF – Caixa Econômica Federal, INSS – Instituto Nacional do Seguro Social, MS – Ministério da Saúde, PETROBRAS – Petróleo Brasileiro S.A.

# %% [markdown]
# ### 2.2. Analise dos Usuários Identificados

# %% [markdown]
# Dos usuários identificados no portal de informação, observamos que a **maioria dos usuários possuem mais que 25 anos de idade**, sendo a grande massa de usuários possuírem entra **25 e 40 anos de idade**. Há uma maior quantidade de acesso por parte do gênero masculino, porém interessante de se observar que na faixa entre os 16 anos  e 25 anos, há uma maioria do gênero feminino requisitando infomações.
# Interessante observar também o grande acesso da ferramenta parte **de usuários com maior formação educacional com o (Ensino Superior Completo)**
# Houve um grande crescimento na procura por informações no período de  Abril, possívelmente ao período que fora decretado o estado pandêmico no Brasil. Ao logo de 2020, **o tema mais procurado foi a respeito de informações sobre COVID**.

# %%
#  Analisando a idade dos usuários mais novo e o mais velho do serviço do canal de informação
print('O usuário mais novo cadastrado tem {} anos e o mais velho {} anos '.format(df_info_idade['idade'].min(), df_reclama_idade['idade'].max() ))
print('A média de idade é de {} anos'.format(df_info_idade['idade'].mean()))
print('A mediana das idades é de {} anos'.format(df_info_idade['idade'].median()))

print('Existem {} cadastros de pessoas com < 15 anos'.format(df_info_idade[['idade']][df_info_idade['idade']<15].value_counts().sum()))
print('Existem {} cadastros de pessoas com > 85 anos'.format(df_info_idade[['idade']][df_info_idade['idade']>85].value_counts().sum()))
# Out:
# O usuário mais novo cadastrado tem -5 anos e o mais velho 105 anos
# A média de idade é de 38.32664671465933 anos
# A mediana das idades é de 36.0 anos
# Existem 67 cadastros de pessoas com < 15 anos
# Existem 266 cadastros de pessoas com > 85 anos

# %%
#Avaliando as idades inferiores a 15 anos 
print(df_info_idade[['IdSolicitante', 'idade','DataNascimento']][df_info_idade['idade']>85].value_counts().sort_values())

#Avaliando as idades  superior a 85
print(df_info_idade[['IdSolicitante', 'idade','DataNascimento']][df_info_idade['idade']<15].value_counts().sort_values())
# Out:
# IdSolicitante  idade  DataNascimento
# 3116515        86     1935-07-07          1
# 3695902        86     1935-04-19          1
# 3687248        226    1795-02-08          1
# 3607525        99     1922-09-25          1
# 3584550        88     1933-10-06          1
#                                        ...
# 1781884        90     1931-03-11          2
# 3174123        90     1931-03-14          3
# 2953913        88     1933-11-12          7
# 2889271        90     1931-11-22         10
# 2707676        99     1922-01-25        119
# Length: 126, dtype: int64
# IdSolicitante  idade  DataNascimento
# 3128287         3     2018-05-27         1
# 3145247         10    2011-11-14         1
# 3474956         1     2020-01-20         1
# 3829144         1     2020-08-19         1
# 3807439         4     2017-06-28         1
# 3802405         1     2020-10-24         1
# 3794703         1     2020-09-29         1
# 3784620         1     2020-08-20         1
# 3656622         1     2020-10-05         1
# 3655421         1     2020-01-12         1
# 3569043         1     2020-10-06         1
# 3559637         1     2020-03-09         1
# 3535020         1     2020-06-08         1
# 3468906         2     2019-09-17         1
# 3838811         1     2020-09-05         1
# 3369855         1     2020-02-02         1
# 3349389         5     2016-06-06         1
# 3345098        -5     2026-03-09         1
# 3193568         1     2020-08-23         1
# 3177240         9     2012-05-11         1
# 3175034         12    2009-11-30         1
# 3173280         13    2008-05-20         1
# 3166051         9     2012-08-20         1
# 3160313         13    2008-09-18         1
# 3905231         9     2012-06-29         1
# 3159663         2     2019-03-30         1
# 3154063         10    2011-07-29         1
# 1863713         1     2020-11-19         1
# 3097851         1     2020-01-28         1
# 3126385         12    2009-09-12         1
# 3124397         1     2020-04-28         1
# 3108989         1     2020-02-19         1
# 3108085         6     2015-07-09         1
# 3107616         1     2020-02-06         1
# 3105071         1     2020-02-17         1
# 1408795         7     2014-01-13         1
# 3100112         1     2020-04-24         1
# 3102153         10    2011-11-23         1
# 3097229         8     2013-12-07         1
# 3141363         14    2007-09-02         1
# 3096694         3     2018-05-04         1
# 3088684         10    2011-12-09         1
# 2791269         4     2017-07-03         1
# 2710669         5     2016-02-22         1
# 2092575         2     2019-08-14         1
# 2042747         7     2014-08-16         1
# 1941358         1     2020-06-26         1
# 3098689         12    2009-02-12         1
# 3370717         1     2020-06-30         2
# 3057208         3     2018-06-06         2
# 3175927         2     2019-08-28         2
# 1165991         2     2019-05-18         2
# 3018389         2     2019-10-05        11
# dtype: int64

# %%
#Agrupamento dos usuários identificados no portal de informação por genero e range de idade
generoXidade        = df_info_idade[['Genero','range_idade']].value_counts().sort_values(ascending= False). reset_index()

#Agrupamento dos usuários identificados no portal de informação por Escolaridade e genero
escolaridadeXgenero = df_info_idade[['Escolaridade',  'Genero']].value_counts().sort_values(ascending= False). reset_index()

#Agrupamento dos usuários identificados no portal de informação por mes e range de idade
idadeXmes = df_info_idade[['mes',  'range_idade']].value_counts().sort_values(ascending= False). reset_index()

#Agrupamento dos usuários identificados no portal de informação por Assunto e range de idade
assuntoXidade        = df_info_idade[['AssuntoPedido','range_idade']].value_counts().sort_values(ascending= False). reset_index().head(25)


plt.figure(figsize=(25,20))
plt.subplot(3,2,1)
sns.barplot(x=0 , y='range_idade' , hue = 'Genero', data = generoXidade, orient = 'h',  palette="pastel")
plt.title('IDENTIFICAÇÃO POR GÊNERO E IDADE (2020)', pad = 20,fontsize = 13, color ='dimgrey', fontweight = 'bold');

plt.subplot(3,2,2)
sns.barplot(x=0 , y='Escolaridade' , hue = 'Genero', data = escolaridadeXgenero, orient = 'h',  palette="pastel")
plt.title('IDENTIFICAÇÃO POR GÊNERO E ESCOLARIDADE  (2020)', pad = 20,fontsize = 13, color ='dimgrey', fontweight = 'bold');

plt.subplot(3,1,2)
sns.barplot(x='mes' , y=0 , hue = 'range_idade', data = idadeXmes, orient = 'v',  palette="pastel")
plt.title('IDENTIFICAÇÃO POR MÊS E IDADE (2020)', pad = 20,fontsize = 13, color ='dimgrey', fontweight = 'bold');

plt.subplot(3,1,3)
sns.barplot(x='AssuntoPedido', y=0 , hue = 'range_idade', data = assuntoXidade, orient = 'v',  palette="pastel")
plt.title('IDENTIFICAÇÃO POR ASSUNTO E IDADE (2020)', pad = 20,fontsize = 13, color ='dimgrey', fontweight = 'bold');

# %% [markdown]
# **O que fazem aqueles que buscam informação?**
#
# Dos usuários identificados, observamos que a maioria dos usuários são majoritariamente pessoas físicas e provenientes de grandes capitais, tal como São Paulo, Rio de Janeiro e Belo Horizonte. O mais interessante é observar que a maior quantidade de acesso é realizado por usuários de Brasília. Seria este um indicador de que quão mais próximo do poder federal, maior é a divulgação do portal ou a familiaridade/facilidade de se utilizar o portal para demandar/questionar os órgãos públicos?

# %%
#Agrupamento dos usuários identificados no portal de informação por localidade
localidade = df_info_idade.groupby(['Municipio_y']).sum().reset_index()

#Agrupamento dos usuários identificados no portal de informação por profissão
profissao = df_info_idade.groupby(['Profissao']).sum().reset_index()

#Agrupamento dos usuários identificados no portal de informação por escolaridade
escolaridade = df_info_idade.groupby(['Escolaridade']).sum().reset_index()


fig, (ax1, ax2, ax3) = plt.subplots(3,1, figsize = (10, 20))
sns.barplot(data=localidade, x='contagem', y ='Municipio_y', order=localidade.sort_values('contagem').tail(20).Municipio_y,  palette="pastel" ,  ax=ax1)
plt.title('QUANTIDADE DE USUÁRIO POR CIDADE (2020)', pad = 20,fontsize = 13, color ='dimgrey', fontweight = 'bold');

sns.barplot(x="contagem", y="Profissao",order=profissao.sort_values('contagem').tail(15).Profissao,  palette="pastel", data=profissao,  ax=ax2)
plt.title('QUANTIDADE DE USUÁRIO POR PROFISSÃO (2020)', pad = 20,fontsize = 13, color ='dimgrey', fontweight = 'bold');

sns.barplot(x = 'contagem', y = 'Escolaridade',  palette="pastel" , data = escolaridade, order=escolaridade.sort_values('contagem').tail(15).Escolaridade, ax=ax3)
plt.title('QUANTIDADE DE USUÁRIO POR ESCOLARIDADE (2020)', pad = 20,fontsize = 13, color ='dimgrey', fontweight = 'bold');

# %% [markdown]
# ### 2.3. Analise dos Órgãos e Assuntos abordados

# %% [markdown]
# Da amostragem dos usuários identificados, de modo geral, observamos que **os principais tópicos abordados são requisições por Acesso à informação, COVID-19, Serviços Públicos e Outros em Economia e Finanças**, entretanto, quando fazemos uma quebra destes assuntos por órgão governamental, verificamos que **os assuntos dominantes são questionamentos a respeito da COVID-19 e Auxílio no Ministério da Cidadania e "Outras em Previdência" no INSS**, refletindo a preocupação dos usuários em referência a COVID e seus efeitos na saúde e economia.
#
# Outras observações interessantes a respeito do dataset é a maior interação entre **usuários que possuem apenas o ensino fundamental com o Ministério da Cidadania (Desenvolvimento Social e Esporte) e quando se quebra os usuários por idade, vemos que o range de idade é entre 16 e 25 anos de idade** e **possuem como principais assuntos Auxílio e COVID-19** . Outro ponto interessante é que **grande parte de interação com vários órgãos provém de usuários com o ensino superior** e que **usuários com mais de 60 possuem maior interação com o INSS e o Ministério da Economia**.

# %%
assunto = df_info_idade[['AssuntoPedido']].value_counts().sort_values(ascending= False). reset_index()
assunto.head(10)
# Out:
#                    AssuntoPedido      0
# 0            Acesso à informação  11813
# 1         Coronavírus (COVID-19)   7157
# 2              Serviços Públicos   6719
# 3  Outros em Economia e Finanças   4035
# 4                        Auxílio   4023
# 5              Educação Superior   3544
# 6          Outros em Previdência   2962
# 7                Outros em Saúde   2945
# 8               Direitos Humanos   1789
# 9              Outros em Energia   1780

# %%
assunto_orgao = df_info_idade[['AssuntoPedido','OrgaoDestinatario']].value_counts().sort_values(ascending= False). reset_index()
assunto_orgao.head(10)
# Out:
#                    AssuntoPedido  \
# 0         Coronavírus (COVID-19)
# 1                        Auxílio
# 2          Outros em Previdência
# 3              Serviços Públicos
# 4                Outros em Saúde
# 5         Coronavírus (COVID-19)
# 6              Outros em Energia
# 7         Outros em Agropecuária
# 8  Outros em Economia e Finanças
# 9                Educação Básica
#
#                                    OrgaoDestinatario     0
# 0  MCIDADANIA - Ministério da Cidadania (Desenvol...  4623
# 1  MCIDADANIA - Ministério da Cidadania (Desenvol...  3668
# 2         INSS – Instituto Nacional do Seguro Social  2884
# 3                        ME - Ministério da Economia  2143
# 4                           MS – Ministério da Saúde  1995
# 5                      CEF – Caixa Econômica Federal  1573
# 6               PETROBRAS – Petróleo Brasileiro S.A.  1250
# 7  MAPA – Ministério da Agricultura, Pecuária e A...  1186
# 8       SUSEP – Superintendência de Seguros Privados  1079
# 9  INEP – Instituto Nacional de Estudos e Pesquis...  1041

# %%
#Agrupamento dos usuários identificados no portal por órgão, assunto, onde os usuários possuem uma idade superior a 25 anos 
assunto_orgao_idade  = df_info_idade[['AssuntoPedido', 'OrgaoDestinatario','range_idade']].value_counts().sort_values(ascending= False). reset_index()
assunto_orgao_idade.head(40)
# Out:
#                     AssuntoPedido  \
# 0          Coronavírus (COVID-19)
# 1                         Auxílio
# 2          Coronavírus (COVID-19)
# 3                         Auxílio
# 4                 Outros em Saúde
# 5           Outros em Previdência
# 6               Serviços Públicos
# 7               Outros em Energia
# 8           Outros em Previdência
# 9           Outros em Previdência
# 10         Coronavírus (COVID-19)
# 11         Outros em Agropecuária
# 12              Serviços Públicos
# 13                        Auxílio
# 14         Coronavírus (COVID-19)
# 15        Outros em Meio Ambiente
# 16               Direitos Humanos
# 17                Outros em Saúde
# 18  Defesa e vigilância sanitária
# 19         Coronavírus (COVID-19)
# 20            Acesso à informação
# 21  Outros em Economia e Finanças
# 22            Acesso à informação
# 23  Outros em Economia e Finanças
# 24  Outros em Economia e Finanças
# 25              Educação Superior
# 26  Outros em Economia e Finanças
# 27                Educação Básica
# 28                Educação Básica
# 29  Outros em Economia e Finanças
# 30         Outros em Agropecuária
# 31  Defesa e vigilância sanitária
# 32  Outros em Comércio e serviços
# 33         Transporte Hidroviário
# 34               Direitos Humanos
# 35              Educação Superior
# 36              Serviços Públicos
# 37            Acesso à informação
# 38            Acesso à informação
# 39              Outros em Energia
#
#                                     OrgaoDestinatario range_idade     0
# 0   MCIDADANIA - Ministério da Cidadania (Desenvol...       25-40  2272
# 1   MCIDADANIA - Ministério da Cidadania (Desenvol...       25-40  1654
# 2   MCIDADANIA - Ministério da Cidadania (Desenvol...       40-60  1530
# 3   MCIDADANIA - Ministério da Cidadania (Desenvol...       40-60  1219
# 4                            MS – Ministério da Saúde       25-40  1164
# 5          INSS – Instituto Nacional do Seguro Social       40-60  1135
# 6                         ME - Ministério da Economia       25-40  1068
# 7                PETROBRAS – Petróleo Brasileiro S.A.       25-40   869
# 8          INSS – Instituto Nacional do Seguro Social         >60   868
# 9          INSS – Instituto Nacional do Seguro Social       25-40   758
# 10                      CEF – Caixa Econômica Federal       25-40   737
# 11  MAPA – Ministério da Agricultura, Pecuária e A...       25-40   654
# 12                        ME - Ministério da Economia       40-60   642
# 13  MCIDADANIA - Ministério da Cidadania (Desenvol...       16-25   639
# 14  MCIDADANIA - Ministério da Cidadania (Desenvol...       16-25   608
# 15  IBAMA – Instituto Brasileiro do Meio Ambiente ...       25-40   519
# 16  MCIDADANIA - Ministério da Cidadania (Desenvol...       25-40   508
# 17                           MS – Ministério da Saúde       40-60   506
# 18  ANVISA – Agência Nacional de Vigilância Sanitária       25-40   505
# 19                      CEF – Caixa Econômica Federal       40-60   503
# 20  MCIDADANIA - Ministério da Cidadania (Desenvol...       25-40   490
# 21       SUSEP – Superintendência de Seguros Privados       40-60   472
# 22                 FUNAI – Fundação Nacional do Índio       25-40   465
# 23                    BACEN – Banco Central do Brasil       25-40   457
# 24       SUSEP – Superintendência de Seguros Privados       25-40   411
# 25                       MEC – Ministério da Educação       25-40   408
# 26                        ME - Ministério da Economia       25-40   395
# 27  INEP – Instituto Nacional de Estudos e Pesquis...       25-40   393
# 28  INEP – Instituto Nacional de Estudos e Pesquis...       16-25   391
# 29                    BACEN – Banco Central do Brasil       40-60   384
# 30  MAPA – Ministério da Agricultura, Pecuária e A...       40-60   369
# 31  ANVISA – Agência Nacional de Vigilância Sanitária       40-60   355
# 32                      CEF – Caixa Econômica Federal       25-40   345
# 33  ANTAQ – Agência Nacional de Transportes Aquavi...       25-40   332
# 34  MCIDADANIA - Ministério da Cidadania (Desenvol...       40-60   318
# 35                       MEC – Ministério da Educação       40-60   316
# 36       ANEEL – Agência Nacional de Energia Elétrica       25-40   316
# 37   MJSP – Ministério da Justiça e Segurança Pública       25-40   296
# 38  MCIDADANIA - Ministério da Cidadania (Desenvol...       40-60   285
# 39               PETROBRAS – Petróleo Brasileiro S.A.       40-60   279

# %%
#Agrupamento dos usuários identificados no portal de informação por órgão e genero
orgaoXgenero        = df_info_idade[['OrgaoDestinatario','Genero']].value_counts().sort_values(ascending= False). reset_index().head(25)

#Agrupamento dos usuários identificados no portal de informação por órgão e escolaridade
orgaoXescolaridade  = df_info_idade[['OrgaoDestinatario',  'Escolaridade']].value_counts().sort_values(ascending= False). reset_index().head(25)

#Agrupamento dos usuários identificados no portal de informação por órgão e range de idade
orgaoXidade         = df_info_idade[['OrgaoDestinatario','range_idade']].value_counts().sort_values(ascending= False). reset_index().head(25)

#Agrupamento dos usuários identificados no portal de informação por Assunto e range de idade
assuntoXidade       = df_info_idade[['AssuntoPedido','range_idade']].value_counts().sort_values(ascending= False). reset_index().head(25)

#Agrupamento dos usuários identificados no portal de informação por órgão e range de idade
orgaoXassunto       = df_info_idade[['OrgaoDestinatario','AssuntoPedido']].value_counts().sort_values(ascending= False). reset_index().head(15)



plt.figure(figsize=(10,40))

plt.subplot(5,1,1)
sns.barplot(x=0 , y='OrgaoDestinatario' , hue = 'Escolaridade', data = orgaoXescolaridade, orient = 'h',  palette="pastel");

plt.subplot(5,1,2)
sns.barplot(x=0 , y='OrgaoDestinatario' , hue = 'Genero', data = orgaoXgenero, orient = 'h',  palette="pastel");

plt.subplot(5,1,3)
sns.barplot(x=0 , y='OrgaoDestinatario' , hue = 'range_idade', data = orgaoXidade, orient = 'h',  palette="pastel");

plt.subplot(5,1,4)
sns.barplot(x=0 , y='OrgaoDestinatario' , hue = 'AssuntoPedido', data = orgaoXassunto, orient = 'h',  palette="pastel");

plt.subplot(5,1,5)
sns.barplot(x=0 , y='AssuntoPedido' , hue = 'range_idade', data = assuntoXidade, orient = 'h',  palette="pastel");

# %% [markdown]
# ## 3.0. Analise do Portal Gov

# %% [markdown]
# ### 3.1. Analise de Palavras Chaves API de Servicos

# %% [markdown]
# Utilizando as informações retiradas da API de Servicos, fizemos uma rápida análise das palavras chaves utilizadas para identificação das páginas criadas e disponibilizadas no portal gov. Nesta busca, encontramos uma grande quantidade de palavras chaves únicas, porém muitas das palavras são de grau mais técnico, o que pode dificultadr o motor de busca (SEO).

# %%
palavra = []
for d  in df_raw_apiServico['palavrasChave.item']:
    for valor in d:
        print(valor.get('item'))
        item=valor.get('item')
        identidade=valor.get('id')
        palavra.append(item)
        
palavra_chaves= pd.DataFrame(palavra)
#palavra_chaves = palavra_chaves[::2].reset_index(drop = True)
palavra_chaves = palavra_chaves.set_axis(["palavra"], axis=1)

df1 = (palavra_chaves['palavra']
              .value_counts()
              .rename_axis('vals')
              .reset_index(name='count'))

a = df1.query('count==1')

a.dropna(subset=['vals'], axis=0, inplace = True)

all_summary = " ".join(s for s in a['vals'])

stopwords = set(STOPWORDS)
stopwords.update(["da", "meu", "em", "você", "de", "ao", "os"])

wordcloud = WordCloud(stopwords=stopwords,
                      background_color='black', width=1600,                            
                      height=800).generate(all_summary)
# Out:
# Antraz
# Bioterrorismo
# Carbúnculo Hemático
# Diagnóstico
# Vigilância virológica
# PCR
# Sorologia
# IGM
# IgG
# Isolamento viral.
# Diagnóstico
# Vigilância virológica
# PCR
# Sorologia
# IGM
# IgG
# Isolamento viral
# Vistas
# Cópias
# Processos Eletrônicos
# Multas
# Caramujo
# Molusco
# Barriga d'água
# Xistose
# Esquistossomose
# Verme
# Verminose
# Febre do caramujo
# Bilharzíaze
# Doença tropical
# Doença negligenciada
# Schistosoma
# Esquistossomo
# Schistosoma mansoni
# Shistosoma americanum
# Caramujo; Biomphalaria; exposição à luz; técn
# Diarreia
# Gastreenterite
# Rotavírus
# Gastroenterite
# Rotaviroses
# Hantavirose
# Hantavírus
# Rickettsioses
# Bartoneloses
# Febre Q.
# Arenaviroses
# Diagnóstico
# Vigilância virológica
# PCR
# Sorologia
# IGM
# IgG
# Isolamento viral
# Hepatites
# Anti-HDV igG(total)
# anti-HDV igM
# HDV-RNA
# Rato
# Urina de rato
# Roedores
# Urina de roedores
# Enchentes
# Mansoni
# Schistosoma mansoni
# Caracol
# Cercária
# Trematódeo
# Biomphalaria
# Esquistossomose
# Hospedeiro intermediário
# Caramujo
# Xistose
# Barriga d´água
# Esquistossome
# Diagnóstico
# área endêmica
# Xistose
# Lagoa da coceira
# Barriga d’água
# Tuberculose
# Laboratório
# Diagnóstico
# Micobactérias
# Micobacterioses
# Referência Nacional
# Helio Fraga
# Tuberculose resistente
# Bactéria resistente
# Resistência bacteriana
# Aedes aegypti
# Aedes albopictus
# Culex quinquefasciatus
# Zika
# Chikungunya
# Infecção
# Dengue
# Filariose
# Laboratório de Controle de Qualidade Animal
# Controle de Qualidade Animal
# Monitoramento sanitário
# Biofármacos
# Hepatite B
# HBV
# Hepatite C
# HCV
# Anemia
# Insuficiência renal crônica
# Doença de Gaucher
# Doença de Crohn
# Artrite reumatoide
# Colite
# Artrite psoriásica
# Psoríase
# Esclerose múltipla
# Paralisia infantil
# Vacinação
# Imunização
# Vacina
# Polio
# Centro de Saúde
# Poliomielite
# naturalização
# Naturalizar-se Brasileiro
# Naturalização Especial
# Medicamentos para o SUS
# Fornecimento de medicamentos
# Fármacos
# Produção de fármacos
# Material biológico
# Material microbiológico
# Fornecimento de Material Biológico
# Vacinas
# Imunização
# Meningite
# Epiglotite
# Infecções do sangue
# Artrite
# Pneumonia
# Difteria
# Tétano
# Coqueluche
# Doenças invasivas
# Otite aguda
# Febre amarela
# Rotavírus
# Sarampo
# Caxumba
# Rubéola
# Catapora
# Varicela e poliomielite
# Banco de imagens
# Imagens
# Iconografia
# Ícone
# Doença de chagas
# Capacitação
# Triatomíneos
# enap
# eppgg
# apo
# Auditoria
# Genealógico
# gene
# cadastro de bens protegidos
# serviços para estados
# sicg
# Reserva
# Reservista
# apresentação obrigatória
# tiro de guerra
# SUS
# Medicamentos
# Lista
# reclamação
# denúncia
# mal tratado
# desrespeito
# servidor público
# ouvidoria
# sugestão
# elogio
# solicitação
# simplificação
# Comunicação em tempo real
# Programa ao vivo
# Integração territorial
# EBC
# ebc
# Empresa Brasil de Comunicação
# Projeto de ensino
# Certificado
# Declaração
# Estabelecimento de saúde
# Medicamento
# Aplicativo SUS
# Consulta
# DigiSUS
# produção de alimentos
# famílias rurais
# baixa renda
# acesso à água
# cisternas
# rural
# tecnologia social
# acesso à água
# tecnologia social
# cisterna
# família
# consumo familiar
# Bebidas
# Vinhos
# Registro de produto
# Colômbia
# Cota Leite
# Leite
# Laticínios
# Certificado de Origem
# Acordo comercial
# Certificado
# Declaração
# Emissão
# demonstrativo
# débito
# lote
# perímetro irrigado
# projeto público de irrigação
# cinema
# filme
# cinemateca
# Supercomputação
# Processamento de alto desempenho
# HPC
# Inteligência artificial
# Computação científica
# kimberley
# CPK
# diamantes
# MODELAGEM MATEMÁTICA
# CIÊNCIAS
# PETRÓLEO
# SEGURANÇA CIBERNÉTICA
# INTELIGÊNCIA ARTIFICIAL
# SUPERCOMPUTAÇÃO
# BIOINFORMÁTICA
# BIGDATA
# MACHINE LEARNING
# MEDICINA
# MEIO AMBIENTE
# mediação
# empresa multinacional
# conflito
# Mestrado
# Doutorado
# Modulagem computacional
# Engenharia
# Biologia
# Pós-graduação
# PPB
# Lei de Informática
# Zona Franca de Manaus
# português
# exame
# português brasileiro
# Paleontologia
# museu
# fósseis
# fóssil
# Vale-Cultura
# Cartão Cultura
# Cultura do Trabalhador
# inpi
# desenhos industriais
# transferência
# mineração
# desmembrar
# jazida
# Transferência
# Titularidade
# GNL
# Despacho
# comércio
# exterior
# bem cultural
# bem imaterial
# tombamento
# normas da previdência
# leis da previdência
# consulta
# importação
# produto veterinário
# pesquisa
# anp
# pontos
# autorização
# FGTS
# Previdência Social
# Declaração
# INPI
# patentes
# invenção
# concessão
# floresta
# madeira
# madereira
# meio ambiente
# saneamento
# educação
# imposto de importação
# cotas
# redução
# Usucapião
# Dominialidade
# Cartório
# AGU
# União
# Declaração
#
# combustível
# automóvel
# gasolina
# álcool
# etanol
# Informações sobre adoção Internacional
# Como adotar crianças no exterior
# Como estrangeiros podem adotar crianças no Br
# apoio a eventos
# financiamento
# ipea
# Ingresso
# Matrícula
# Inscrição
# renúncia do título minerário
# fechamento de mina
# mineração
# Matrícula
# Inscrição
# Ingresso
# Transporte Ferroviário
# Transporte
# Ferrovia
# Inscrição
# Auxílio
# Creche
# auxílio técnico
# capacitação
# saúde
# expurgo
# indisponível
# aneel
# Aneel
# entrar em operação
# operação comercial
# nada consta
# certificado
# inadimplência
# Inscrição
# Auxílio
# Óculos
# Peticionamento Eletrônico
# Protocolo Eletrônico
# Sistema Eletrônico de Informações
# Usuário externo
# Processo Eletrônico
# Processo administrativo
# Acesso ao SEI
# Protocolização
#
# piloto
# brevê
# helicóptero
# piloto comercial
# ANAC
# Inscrição
# Auxílio
# Transporte
# Auxílio
# Alimentação
# Inscrição
# Inscrição
# Auxílio
# Atleta
# anp
# autorização
# GLP
# trânsito
# acidente
# BR
# rodovia
# clima
# Amazônia
# defesa
# Barreiras
# Exportação
# Demanda
# Acesso a Mercados
# Barreiras Tarifárias
# Barreiras Não Tarifárias
# Mercados Externos
# Impacto Comercial
# Restrições ao Comércio Nacional
# MMA
# Licença
# Habilitação
# Aviônico
# Grupo Motopropulsor
# Célula
# Mecânico de Manutenção Aeronáutica
# Aneel
# energia elétrica
# telecomunicações
# infraestrutura
# CCC
# SRG
# subrogados
# Aneel
# tarifa social
# homologação
# relatório
# Aneel
# Preços de medicamentos
# SCMED
# recurso
# SCMED
# monitoramento de mercado
# preços de medicamentos
# CA
# CAEPI
# equipamento de proteção individual
# Defesa em processo sancionador
# Processo sancionador
# Fiscalização
# EBN
# Renúncia
# Outorga
# avião
# combustível
# anp
# INPI
# patentes
# transferência
# Sine
# Empregador
# Cadastro
# Emprego
# Vaga de emprego.
#
#
# levantamento aéreo
# autorização
# espaço aéreo nacional
# Aneel
# Reunião Pública
# Sustentação oral
# Ordem de preferência no julgamento
# Aneel
# Relacionamento com consumidor
# Registro de reclamação
#
# Emprego
# Intermediação de mão de obra
# Dados abertos
# Aneel
# Participação acionária
# Geração de energia elétrica
# Aneel
# Participação Pública
# participação Social
# Audiência Pública
# Consulta Pública
# rede privada
# energia elétrica
# aneel
# Aneel
# Reuniões Públicas
# Pautas e atas
# Aneel
# Consulta processual
# Obtenção de cópia
# Curso
# Desenho
# Pintura
# transmissão
# aprovação
# aneel
# anm
# área
# englobar
# certificado
# Enem
# Ensino Médio
# Sisbacen
# Registrato
# Cadastro
# Sistema
# Cursos de Graduação
# Sistema Estadual
# Alteração de Denominação de Curso
# Cadin
# União
# Devedor
# SCMED
# monitoramento de mercado
# preços de medicamentos
# Cheque sem fundo
# CCF
# Relatório
# Leishmaniose Tegumenta
# Diagnóstico molecular
# Diagnóstico molecular
# catadores
# latinhas
# reciclagem
# MapaSAN
# Assistência Social
# Segurança Alimentar e Nutricional
# transferência
# extinção
# aneel
# Aneel
# CDA
# Cadastro institucional
# Aneel
# Biblioteca virtual
# Legislação do setor elétrico
# energia no campo
# luz
# homologação de relatório
# Aprovação
# Individualização da Produção
# Terra
# Aneel
# DRO
# Central Geradora
# Eólica
# Fotovoltaica
# Termelétrica
# aneel
# outorgadas
# estudo de terreno
# Aneel
# atendimento
# energia
# precário
# sistema isolado
# energia elétrica
# aneel
# certidão
# naturalização
# cnn
#
# Agendamento
# Orientação
# Pesquisa
# Segurança jurídica
# Expertise em publicidade legal
# Alcance global
# Celeridade
# ebc
# EBC
# Empresa Brasil de Comunicação
# bens culturais tombados
# sicg
# banco de dados de bens tombados
# tombamento
# Estágio
# Convênio
# Estagiar
# Processo seletivo
# Vestibular
# Educação profissional técnica
# integrado e subsequente
# Ficha Catalográfica.
# Monografia
# Dissertação
# Tese
# Refino
# Alteração
# Instalações
# município
# luz pública
# faturamento
# radioatividade
# radiatividade
# capacitação
# radioproteção
# dosimetria
# IRD
# CIE
# CRNM
# RNE
# RNM
# Cédula de Identidade de Estrangeiro
# Carteira de Registro Nacional Migratório
# Recadastramento Extemporâneo
# Estrangeiro
# Imigrante
# auxílio
# investigações
# origem
# Biocombustíveis
# Produtor
# Armazenagem
# segurança pública
# cidadania
# veículos
# mandados de prisão
# desaparecidos
# procurados
# participação cidadã
# açúcar
# União Européia
# exportação
# redução fiscal
# importação
# Certificado
# Agendamento
# Orientação
# Normalização
# Unidade piloto
# Unidade temporária
# Unidade especial
# solvente
# autorização
# produtor
# desaparecido
# desaparecida
# localização
# Sinesp
# consulta
#
# Riquetsioses
# Carrapatos
# Pulgas
# Piolhos
# Bio agentes
# Identificação de vetores
#
# Matrícula
# Educação Superior
# Graduação
# Pós-Graduação
# Sinesp
# Cidadão
# Foragido
# Procurado
# Criminosos
# Inscrição Suframa
# Cadastro Suframa
# Suframa
# Diploma
# 2a via
# Registro escolar
# consulta
# mandado de prisão
# Sinesp
# porto organizado
# atividade portuária
# instalações náuticas
# TUP
# IP4
# IPT
# turismo
# disponibilidade de espaço físico
# águas públicas
# terreno
# Encceja
# Certificação
# Ensino Médio
# acordo internacional
# transferência
# benefício
# manutenção
# Enem
# certificação
# declaração
# obras raras
# preservação cultural
# restauração
# Diploma
# Certificado
# Documento
# reformas na casa
# mal de Chagas
# vigilância sanitária
# SECOM
# Itamaraty
# MRE
# Exportar
# Captar investimento
# empresa brasileira
# exterior
# Defesa
# material militar
# produtos de defesa
# autorização
# fertilizante
# inoculante
# corretivo
# solo
# produtos químicos
# anm
# cisão
# empresas
# transferência
# direito minerário
# Credenciamento de Remetente
# Cadastro de Rementente
# Cadastro de Fornecedor
# IPHAN
# IPHAN
# Autorização para Saída de Obras de Arte do Pa
# ortopedia
# trauma ortopédico
# alta complexidade
# Censo
# Capitais estrangeiros
# Empresas
# Fundos de investimentos
# Regime domiciliar
# Atestado
# Educação
# EBN
# Frota
# Embarcação
# arrendatário
# arrendamento parcial
# manifesto de mina
# direito minerário
# concentração
# monopólio
# fusão
# INPI
# marcas
# transferência
# aditar
# mineração
# substância
# anm
# denuncia
# irregularidades
# área de mineração
# denunciar
# Centrais
# Petroquímica
# Gasolina A
# antaq
# cargas
# transporte
# Auditoria Independente
# Processos Produtivos Básicos
# PPB
# Sistemas de Qualidade
# Projetos Industriais
# mudança
# permissão
# anm
# Obter;
# Prorrogação;
# Licenciamento
# registro de licença
# pesquisa
# anm
# substância
# comunicar
#
# dispensa de título minerário
# dispensa
# titulo minerario
# Obter;
# Renovação;
# Registro de Extração
# obter;
# solicitar
# renovação;
# permissão de lavra garimpeira.
# transferência
# direitos minerários
# incorporação
# anm
# cessão parcial
# concessão de lavra
# mineração
# aerolevantamento
# geofísico
# reconhecimento
# geológico
# cessão total
# transferência
# direito minerário
# anm
# autorização de pesquisa
# Processamento de gás
# Transferência
# Titularidade
# Refinaria
# Cessão
# Arrendamento
# fósseis
# paleontologia
# exportação
# fóssil
# cadastro de bens culturais inventariados
# serviços para pesquisadores
# sicg
# cessão total
# concessão de lavra
# ANM
# Combustível
# Produtora
# Planta
# cessão
# cessão parcial
# direito de requerer a lavra
# Formulador
# Combustível
# Transferência
# Retomada
# Operações
# Refinaria
# INPI
# programas de computador
# transferência
# anm
# transferência
# herdeiro
# causa mortis
# anm
# falência
# empresas
# transferência
# direito minerário
# anm
# fusão
# transferência
# empresa
# direito minerário
# garrafa de água
# importação
# água mineral
# EBN
# OCORRÊNCIAS
# COMUNICAR
# Cebas
# Monitoramento
# Cebas educação
# SisCebas
# cessão
# cessão total
# direito de requerer a lavra
# água mineral
# rótulo
# água
# atendimento
# polícia rodoviária
# rodovia
# Faixa de domínio
# Rodovias
# DNIT
# Auditoria Independente
# Processos Produtivos Básicos
# PPB
# Sistemas de Qualidade
# Projetos Industriais
# Teste
# Carga
# Autorização
# PDDE
# Unidade Executora
# UEx
# Biocombustíveis
# Ampliação
# Modificação
# PNATE
# transporte escolar
# FNDE
# Fracionamento de imóveis
# Desmembrar área
# SPU
#
#
# Imóvel da União
# SPU
# Consolidar
# certificado
# registro
# trading companies
# ZPE
# Indústria
# Exportação
# SICG
# IPHAN
# Centro Nacional de Arqueologia
# buscar unidade IPHAN
# PNAE
# Alimentação Escolar
# FNDE
# Permissão
# lavra garimpeira
# ANM
#
#
#
# mudança
# regime
# pesquisa
# anm
# poligonal
# mineração
# anm
# PNAE
# Alimentação escolar
# inadimplência
# Acompanhamento
# Pedagógico
# Acadêmico
# DNIT
# DENIT
# Multas de Trânsito
# Infração de Trânsito
# Nada Consta
# Lubrificantes
# Transferência
# Tecnologia
# Banda Larga na Escola
# PBLE
# Internet na Escola
# Conectividade Rural
# 4G Anatel
# Internet Rural
# NR 37
# Norma Regulamentadora 37
# Mudança de locação
# MEC
# Protocolo
# Peticionamento
#
# paleontologia
# fóssil
# fósseis
# Compensar pagamento
# DARF
# Pagamento indevido
# Ressarcimento
# Crédito por pagamento em duplicidade
#
# Ex-tarifário
# BK
# BIT
# TEC
# Yersinia pestis
# Sorologia
# Zoonoses
# Rato
# Peste negra
# Pulga
# Inscrição
# Atividade
# Psicologia
# INPI
# marcas
# recurso
# mineração
# anm
# cadastro
# barragem
# SIGBM
# Arbovirus
# Zika
# Febre amarela
# Diagnóstico
# Laboratório de referência
# INPI
# indicações geográficas
# oposição
# Atendimento
# Saúde
# Serviço
# Solicitação
# Desbloqueio
# Restaurante Universitário
# naturalização
# cpn
# e-certidão
# licenciamento ambiental
# presença de bens protegidos
# sicg
# verificar bens culturais protegidos
# Produtos controlados
# Substâncias, plantas e medicamentos sujeitos
# Autorização para Exportação (AEX).
# Prioridade
# Financiamento
# Fundo da Marinha Mercante
# Interesse público
# Suspensão
# Alteração
# Direito
# Antidumping
# Medida compensatória
# Defesa comercial
# Avaliação
# educação
# sst
# fundacentro
# app fundacentro
# bens culturais procurados
# patrimonio cultural brasileiro
# sicg
# bens culturais desaparecidos
# benefício fiscal
# infraestrutura
# energia elétrica
# AGÊNCIA NACIONAL DE ENERGIA ELÉTRICA - ANEEL
# arrendamento
# direito minerário
# anm
# concessão de lavra
# Hantavírus
# Diagnóstico
# Vigilância epidemiológica
# cessonário
# cedente
# anm
# cessão
# parcial
# direito minerário
# BIT
# Ex-Tarifário
# BK
# TEC
# Ex-tarifário
# BK
# BIT
# TEC
# Ex-tarifário
# BK
# BIT
# TEC
# Ex-tarifário
# BK
# BIT
# TEC
# anm
# mineração
# cessão parcial
# registro de licença
# transmitância luminosa
# vidros
# películas
# homologar medidor
# habilitação
# laboratório
# xitopatologia
# Alerta
# tecnovigilância
# produto para saúde
# notificação de ação de campo
# alerta de tecnovigilância
# ANVISA
# atracar
# desatracar
# porto sem papel
# navio
# barco
# estadia no porto
# troca
# licenciamento
# dnpm
# Registro
# regularização
# alimento
# registro de alimento
# regularização de alimento
# ANVISA
# Registro
# regularização
# alimento
# registro de alimento
# regularização de alimento
# ANVISA
# Registro
# regularização
# alimento
# registro de alimento
# regularização de alimento
# ANVISA
# Registro
# regularização
# alimento
# registro de alimento
# regularização de alimento
# ANVISA
# registro de licença;
# licenciamento;
# anm
# Registro
# regularização
# alimento
# registro de alimento
# regularização de alimento
# ANVISA
# voltar a ser brasileiro
# voltar para o Brasil
# readquirir nacionalidade brasileira
# revogação de perda de nacionalidade brasileir
# reforma agrária
# cadastro
# atualização
# DENATRAN
# multa
# multa de trânsito
# multa de transito
# infração
# Registro
# regularização
# alimento
# registro de alimento
# regularização de alimento
# ANVISA
# Registro
# regularização
# alimento
# registro de alimento
# regularização de alimento
# ANVISA
# Stricto sensu
# mestrado
# pós-graduação
# prorrogação
# pesquisa
# anm
# relatório parcial
# alvará
# mineração
# anm
# relatório
# relatório final
# pesquisa
# Avaliação de incentivos
# sudam
# siav
# incentivos fiscais
# DENATRAN
# CNH
# Carteira de motorista
# CNH Digital
# Certificação
# Beneficiário
# Expedição de Documento
# anm
# permissão de lavra garimpeira
# cessão parcial
# ANVISA
# ensaios clínicos
# medicamento novo
# DDCM
# Investimento Estrangeiro
# Capital Internacional
# Registro
# RDE
# IED
# Publicação
# IFC
# Editora
# Transferência;
# Núcleo de Inovação Tecnológica;
# Inovação;
# Propriedade Intelectual;
# Licenciamento;
# Cessão.
# Proteção
# Núcleo de Inovação Tecnológica
# Inovação
# Propriedade Intelectual
# Patente
# Programa de computador
# Software
# Desenho industrial
# Marca
# anm
# requerimento
# cessão parcial
# Requerimento de Lavra
# remição
# aforamento
# comprar 17% pertencente à União
# SPU
# resgatar
# domínio
# direito de adquirir
# Prescrição
# Decadência
# Dívida Ativa da União
# Cancelar cobrança
# CADIN
# Duplicidade de pagamento
# Certidão de Imóveis da União
# verificação de autenticidade
# Certidão SPU
# permissão
# TAU
# sustentável
# comunidade tradicional
# contrato outorga
# RIP
# termo de uso
# aforamento
#
# gestão das praias
# praias
# gestão municipal
# cessão total
# registro de licença
# anm
# DARF
# Imóvel da União
# extinta Rede Ferroviária Federal
# 2ª via
# SPU
# Certificação de boas práticas
# boas práticas de fabricação
# boas práticas de distribuição e armazenagem
# CBPF
# CBPDA
# ANVISA
# permissão lavra garimpeira
# cessão total
# anm
#
#
# Emprego
# Intermediação de mão-de-obra
# Mapa
# Certificação de imóvel rural
# Georreferenciamento de imóvel rural
# SIGEF
# Atividade Rural
# Comprovação de Atividade Rural
# Atendimento Presencial
# lago azul
# venda direta
# aquisição direta
# compra
# união
# venda
# proposta
#
# histórico financeiro
# DARF
# Imóvel da União
# SPU
# regularização de débitos
#
#
#
#
#
# Bolsas
# Extensão
# Edital
# HCVRNA
# hepatite A
# Anti-HCV
# Certificação de boas práticas
# boas práticas de fabricação
# boas práticas de distribuição e armazenagem
# CBPF
# CBPDA
# ANVISA
# Certificação de boas práticas
# boas práticas de fabricação
# boas práticas de distribuição e armazenagem
# CBPF
# CBPDA
# ANVISA
# cessão total
# requerimento
# anm
# Certificação de boas práticas
# boas práticas de fabricação
# boas práticas de distribuição e armazenagem
# CBPF
# CBPDA
# ANVISA
# Certificação de boas práticas
# boas práticas de fabricação
# boas práticas de distribuição e armazenagem
# CBPF
# CBPDA
# ANVISA
# Certificação de boas práticas
# boas práticas de fabricação
# boas práticas de distribuição e armazenagem
# CBPF
# CBPDA
# ANVISA
# Certificação de boas práticas
# boas práticas de fabricação
# boas práticas de distribuição e armazenagem
# CBPF
# CBPDA
# ANVISA
# Atualização de dados cadastrais
# Contrato de Compra e Venda ex-RFFSA
# Ocupação de imóvel Rede Ferroviária
# DARF
# parcelamento
# imóvel da União
# deferido
# SPU
# renegociação 2009
#
# situação do imóvel
# benfeitorias
# responsável por imóvel da União
#
#
# Certificação de boas práticas
# boas práticas de fabricação
# boas práticas de distribuição e armazenagem
# CBPF
# CBPDA
# ANVISA
# Certificação de boas práticas
# boas práticas de fabricação
# boas práticas de distribuição e armazenagem
# CBPF
# CBPDA
# ANVISA
# Certificação de boas práticas
# boas práticas de fabricação
# boas práticas de distribuição e armazenagem
# CBPF
# CBPDA
# ANVISA
# Certificação de boas práticas
# boas práticas de fabricação
# boas práticas de distribuição e armazenagem
# CBPF
# CBPDA
# ANVISA
# Autorização
# Pesquisa
# CNPq
# Importação
# mineração
# lavra
# anm
# requerimento de lavra
# Certificação de boas práticas
# boas práticas de fabricação
# boas práticas de distribuição e armazenagem
# CBPF
# CBPDA
# ANVISA
# transferência de titularidade
# alteração
# drawback
# Certificação de boas práticas
# boas práticas de fabricação
# boas práticas de distribuição e armazenagem
# CBPF
# CBPDA
# ANVISA
# diamantes
# exportação
# kimberley
# CPK
# CNCD
# Certificação de boas práticas
# boas práticas de fabricação
# boas práticas de distribuição e armazenagem
# CBPF
# CBPDA
# ANVISA
# Certificação de boas práticas
# boas práticas de fabricação
# boas práticas de distribuição e armazenagem
# CBPF
# CBPDA
# ANVISA
# Usar imóvel da União para outro fim
# CUEM
# CDRU
# Permuta
# SPU
# TAUS
# extração
# autorização especial
# anm
# Guia de Utilização
# Registro de Extração
# obras públicas
# órgãos públicos
# anm
# mineração
# suspensão de lavra
# processo minerário
# dominialidade
# certidão SPU
# usucapião
# extrajudicial
# declaração de propriedade
#
#
# Certidão de Imóveis da União
# SPU
# Certidão Negativa de Débitos Patrimoniais
# Certidão de Situação de Ocupação/Aforamento
#
# Uso de imóvel público
# ocupação
# terra pública
# aforamento
# concessão fundiária
# requerimento de regularização
# CDRU
# CUEM
# moradia ribeirinho
#
# manutenção
# barragens
# segurança
# perfuração
# poço
# água
# cadastro
# mineração
# siscomex
# comércio mineral
# alterar cadastro
# audiovisual
# norte
# nordeste
# cadastrar bens protegidos
# serviços para municípios
# sicg
# Celebração
# Convênio
# Estágio
# museu
# financiamento
# modernização
# Emissão
# Declaração
# Certidão
# IPHAN
# SICG
# patrimônio cultural brasileiro
# SICG
# Arqueológicos
# Cadastramento
# Bens Arqueológicos
# Concursos públicos
# Participação
# Magistério
# Inscrição
# Curso
# Evento
# Bolsa
# Ação
# Extensão
# teste de nivelamento
# curso de línguas
# curso a distância
# saneamento
# esgoto
# funasa
# inventário
# florestas
# bioma
# MICE
# Negócios e Eventos
# Captação
# Promoção
# Turismo
# Congresso
# Leilões de Energia
# Habilitação Técnica
# Sistema AEGE
# ANATO
# ITB
# BTL
# IMEX
# FIEXPO
# IFTM
# feiras
# evento
# FIT
# FITPAR
# WTM
# turismo
# internacional
# embratur
# FITUR
# Hanseníase
# Lepra
# Ambulatório
# Atendimento médico
# Tratamento
# Consulta médica
# Atendimento ambulatorial
# Foto
# Embratur
# Vídeo
# Brasil
# transparência
# servidor público
# expulsos
# exonerados
# demissões
# demitidos
# importação
# animais
# material genético
# importação
# animais
# material genético
# Renovação
# Auxílio
# Alimentação
# exportação
# agropecuária
# habilitação
# armazéns
# casa
# saneamento
# água e esgoto
# empresas
# punidas
# corrupção
# nome sujo com o governo
# Renovação
# Auxílio
# Atleta
# Infectologia
# Doenças infecciosas
# Infecção
# Diagóstico especializado
# Diagnóstico doenças
# Consulta ambulatorial
# Consulta doença infecciosa
# Micobacterioses
# Micoses
# medicamento
# exportação
# autorização
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-89-a5ae69f56a08> in <module>
#       1 palavra = []
#       2 for d  in df_raw_apiServico['palavrasChave.item']:
# ----> 3     for valor in d:
#       4         print(valor.get('item'))
#       5         item=valor.get('item')
#
# TypeError: 'float' object is not iterable

# %%
palavra_chaves= pd.DataFrame(palavra)
#palavra_chaves = palavra_chaves[::2].reset_index(drop = True)
palavra_chaves = palavra_chaves.set_axis(["palavra"], axis=1)

df1 = (palavra_chaves['palavra']
              .value_counts()
              .rename_axis('vals')
              .reset_index(name='count'))

a = df1.query('count==1')

a.dropna(subset=['vals'], axis=0, inplace = True)

all_summary = " ".join(s for s in a['vals'])

stopwords = set(STOPWORDS)
stopwords.update(["da", "meu", "em", "você", "de", "ao", "os"])

wordcloud = WordCloud(stopwords=stopwords,
                      background_color='black', width=1600,                            
                      height=800).generate(all_summary)

fig, ax = plt.subplots(figsize=(16,8))            
ax.imshow(wordcloud, interpolation='bilinear')       
ax.set_axis_off()
plt.imshow(wordcloud)
